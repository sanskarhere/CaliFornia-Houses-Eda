# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'../Dataset/housing.csv')

# %%
# Out:
# 'c:\\Users\\ASUS\\Desktop\\California Datase\\Notebook'
